# %%
from GridWorld import GridWorld
from Agent import Agent

# %%
env = GridWorld(6,6)
env.set_start((0,0),0)
env.set_goal((5,5),2)
env.set_penalty(step_cost=-0.1,boundry_cost=-0.5)
# trap_cell1 = (2,1)
# trap_cell2 = (1,3)
# env.set_reward(trap_cell1,-2)
# env.set_cell_name(trap_cell1,'T')
# env.set_reward(trap_cell2,-2)
# env.set_cell_name(trap_cell2,'T')
env.show_grid()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 env = GridWorld(6,6)
#       2 env.set_start((0,0),0)
#       3 env.set_goal((5,5),2)
#
# File C:\pratham_prabhu\02_AIML\sem2\DRL\GridWorld.py:14, in GridWorld.__init__(self, rows, columns)
#      12 self.goal = ()
#      13 self.start = ()
# ---> 14 self.grid = self.prepare_grid()
#      15 self.rewards = []
#      16 self.action_map = {0:'-',1:'↑',2:'↓',3:'←',4:'→'}
#
# File C:\pratham_prabhu\02_AIML\sem2\DRL\GridWorld.py:26, in GridWorld.prepare_grid(self)
#      24 for row in range(self.rows):
#      25     for column in range(self.columns):
# ---> 26         grid[(row,column)] = [self.step_cost,'.'] #Key is a position tuple, value= (reward,name).
#      27 return grid
#
# AttributeError: 'GridWorld' object has no attribute 'step_cost'

# %%
a2 = Agent(env)
for episode in range(50): 
    a2.execute_action(epsilon=0.1,verbose=False)
    a2.update_state_values() 
else:
    print("DONE!")

# %%
env.print_grid_contents(a2.V)
a2.get_greedy_policy()
updated_greedy_grid = env.grid_to_action_map(a2.greedy_grid)
env.print_grid_contents(updated_greedy_grid)

# %%
a2.reset()
a2.execute_action(epsilon=0.4,verbose=True)

# %%
env.show_move(a2.prev_states_list,a2.action_set)
