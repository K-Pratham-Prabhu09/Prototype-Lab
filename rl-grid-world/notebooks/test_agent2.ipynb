# %%
# %load_ext autoreload
# %autoreload 2
# %run init.py
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
#  C:\pratham_prabhu\01_AIML\prototype-bank\Prototype-Lab\rl-grid-world\utils Path addedd successfully

# %%
import numpy as np
from GridWorld import GridWorld
from Agent import Agent

# %%
# %%
env2 = GridWorld(6,6)
env2.set_start((0,0),0)
env2.set_goal((5,5),2)
env2.show_grid()
env2.set_penalty(step_cost=-1,boundry_cost=-1)
# Out:
# [S][.][.][.][.][.]
#
# [.][.][.][.][.][.]
#
# [.][.][.][.][.][.]
#
# [.][.][.][.][.][.]
#
# [.][.][.][.][.][.]
#
# [.][.][.][.][.][G]

# %%
a2 = Agent(env2)
a2.execute_action(epsilon=0,verbose=False,stopping_iter=900)
env2.print_grid_contents(a2.V)
print('-----------')
env2.show_move(a2.prev_states_list,a2.action_set)
a2.get_greedy_policy()
print('-----------')
a2.execute_action(epsilon=0.8,verbose=False,stopping_iter=900)
# Out:
# [-1.71][-1.62][-1.12][-0.55][-1.13][-1.42]
#
# [-0.59][-0.71][-1.0][-0.69][-1.03][-1.21]
#
# [-0.41][-0.52][-0.63][-0.59][-0.49][-0.67]
#
# [0][-0.1][-0.49][-0.48][-0.2][-0.67]
#
# [0][0][-0.1][-0.28][-0.11][-0.47]
#
# [0][0][0][0][0][0]
#
# -----------
# [←→←↑↑→↓→←↑→↑↑↑→→←↑→←→↑↓→][←←←→→↑←↓←←↑↑←→→↑↑→↓][↓←↓←↓←↓←↓][↑↓→→→][→←→↓→↓→→←↓→][↓↑←↓→→→↓←→↑↓←→→↓]
#
# [↑↑↓↑][→←↑→→←↓][←↓↓↑→←→↑→↑↑←][↑↓→←←→↑][↑→→↓→→↑←↑↑↑][↓↓←←→→←↑←↑↓→→→↓]
#
# [→←→→][↑←↑←→][→↓↓↑→↑↓][↑→↓←↓↑][↑←←↑][↓←↑←→→↓]
#
# [.][↑][↑↑↑←→][↓↓↑←↓][←→][←→→↑↓↓→↓]
#
# [.][.][↑][↑←→][↑][↑↑→→↓]
#
# [.][.][.][.][.][G]
#
# -----------

# %%
env2.print_grid_contents(a2.V)
print('-----------')
env2.show_move(a2.prev_states_list,a2.action_set)
a2.get_greedy_policy()
print('-----------')

updated_greedy_grid = env2.grid_to_action_map(a2.greedy_grid)
env2.print_grid_contents(updated_greedy_grid)
# Out:
# [-1.77][-1.62][-1.12][-0.55][-1.13][-1.42]
#
# [-1.04][-0.97][-1.0][-0.69][-1.03][-1.21]
#
# [-1.79][-1.3][-0.9][-0.7][-0.49][-0.67]
#
# [-2.26][-1.86][-0.98][-0.55][-0.29][-0.67]
#
# [-2.4][-2.35][-0.85][-0.28][-0.2][-0.47]
#
# [-2.13][-2.22][-1.16][-0.46][0][0]
#
# -----------
# [↑↓][.][.][.][.][.]
#
# [→→↓↓↓][←←↓][.][.][.][.]
#
# [↓↑←←←↓→→↑↓↓→←↓↓↓][↓↑↓↓↓→↓↓][←→↓][←][.][.]
#
# [↑↑→→↓↑↑↓↓↑←→↓↓↓→↓→↓↑↓↑→↑↓←↑→][←←↑→↓←→↓←↓↓↓←←↑↓↓↑→][↓↓↑↓←→][→][↓][.]
#
# [↑→→↓↑↑←←↓←↑→↑↑↑↑↓↑→→↓↓↑←→↑→←↑↓↑][←↓↑↓↓←↓←↓↓↓↓←↑←↑←↑↓→↓↓←←↑↓←↓↓][↑↑↓←←][.][↓][.]
#
# [→↓↑↑↑↑↓←→←↓←←↑↓↑↓↓→↑][↓→↓↓↓↑←↑↑↑↑↑↑→↑→←→←↑↓↑↓→↓↑↑↑←][←←←←↓→→→↓↓←↑][←←←][→][G]
#
# -----------
# [↓][↓][→][↓][←][←]
#
# [→][→][→][↑][↓][↓]
#
# [↑][→][→][→][↓][←]
#
# [↑][→][→][↓][↓][←]
#
# [↓][→][→][→][↓][↓]
#
# [→][→][→][→][→][-]

# %%
a1 = Agent(env2)
for episode in range(500): 
    a1.execute_action(epsilon=0.1,verbose=False,stopping_iter=900)

env2.print_grid_contents(a1.V)
env2.show_move(a1.prev_states_list,a1.action_set)
# Out:
# [Warning] Force Stopping after 900 iterations, goal not found...
# [Warning] Force Stopping after 900 iterations, goal not found...
# [-10.0][-10.0][-10.0][-10.0][-10.0][-10.0]
#
# [-10.0][-10.0][-10.0][-10.0][-10.0][-10.0]
#
# [-10.0][-10.0][-10.0][-10.0][-10.0][-10.0]
#
# [-10.0][-10.0][-10.0][-10.0][-10.0][-10.0]
#
# [-10.0][-10.0][-10.0][-10.0][-10.0][-10.0]
#
# [-10.0][-10.0][-10.0][-10.0][-10.0][0]
#
# [↑→↑↓↓↑↓↓][→←][↑→↓][→][→→][↑←↑↓]
#
# [↑↑↓↓↑→↓][↑←][↑←][←][↓][→↓↓]
#
# [↑↓←↑↓][.][.][→↑][→↑→←←→→][←↓↑←←↓→↓]
#
# [↓↑→][←→][↓→→][←→][↑↑][←↑↓]
#
# [→][→↑][↑←][.][.][↓]
#
# [.][.][.][.][.][G]

# %%
a1.get_greedy_policy()
updated_greedy_grid = env2.grid_to_action_map(a1.greedy_grid)
env2.print_grid_contents(updated_greedy_grid)
# Out:
# [→][→][→][→][↓][↓]
#
# [↓][→][→][→][↓][↓]
#
# [↓][→][↓][↓][↓][↓]
#
# [↓][→][→][→][↓][↓]
#
# [→][→][→][→][→][↓]
#
# [→][→][→][→][→][-]

# %%
a1.reset()
a1.execute_action(epsilon=0.0,verbose=True,stopping_iter=150)
env2.show_move(a1.prev_states_list,a1.action_set)
# Out:
# [1]:Attempting → at (0, 0)
# TD || (0, 0)[V=-10.0]||(0, 1)[V=-10.0] || V new for (0, 0)=-10.0
# [2]:Attempting → at (0, 1)
# TD || (0, 1)[V=-10.0]||(0, 2)[V=-10.0] || V new for (0, 1)=-10.0
# [3]:Attempting → at (0, 2)
# TD || (0, 2)[V=-10.0]||(0, 3)[V=-10.0] || V new for (0, 2)=-10.0
# [4]:Attempting → at (0, 3)
# TD || (0, 3)[V=-10.0]||(0, 4)[V=-10.0] || V new for (0, 3)=-10.0
# [5]:Attempting ↓ at (0, 4)
# TD || (0, 4)[V=-10.0]||(1, 4)[V=-10.0] || V new for (0, 4)=-10.0
# [6]:Attempting ↓ at (1, 4)
# TD || (1, 4)[V=-10.0]||(2, 4)[V=-10.0] || V new for (1, 4)=-10.0
# [7]:Attempting ↓ at (2, 4)
# TD || (2, 4)[V=-10.0]||(3, 4)[V=-10.0] || V new for (2, 4)=-10.0
# [8]:Attempting ↓ at (3, 4)
# TD || (3, 4)[V=-10.0]||(4, 4)[V=-10.0] || V new for (3, 4)=-10.0
# [9]:Attempting → at (4, 4)
# TD || (4, 4)[V=-10.0]||(4, 5)[V=-10.0] || V new for (4, 4)=-10.0
# [10]:Attempting ↓ at (4, 5)
# GOAL ATTAINED IN 11 iterations and 10 actions with return G = -10
# [→][→][→][→][↓][.]
#
# [.][.][.][.][↓][.]
#
# [.][.][.][.][↓][.]
#
# [.][.][.][.][↓][.]
#
# [.][.][.][.][→][↓]
#
# [.][.][.][.][.][G]
